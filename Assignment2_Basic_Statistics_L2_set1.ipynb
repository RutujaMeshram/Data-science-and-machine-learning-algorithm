# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **1. Look at the data given below. Plot the data, find the outliers and find out μ,σ,σ^2**
#
#
# **[24.23,25.53,25.41,24.14,29.62,28.25,25.81,24.39,40.26,32.95,91.36,25.99,39.42,26.71,35.00]**

# %%
x=pd.Series([24.23,25.53,25.41,24.14,29.62,28.25,25.81,24.39,40.26,32.95,91.36,25.99,39.42,26.71,35.00])

# %%
name = ['Allied Signal','Bamkers Trust','General Mills','ITT Industries','J.P.Morgan & Co.','Lehman Brothers','Marriott','MCI','Merrill Lynch','Microsoft','Morgan Stanley','Sun Microsystems','Travelers','US Airways','Warner-Lambert']

# %%
plt.figure(figsize=(6,8))
plt.pie(x, labels = name,autopct='%1.0f%%')
plt.show()

# %%
# Box plot to find outliars

sns.boxplot(x)
# Out:
# <Axes: >

# %%
x.mean()
# Out:
# 33.27133333333333

# %%
x.var()
# Out:
# 287.1466123809524

# %%
x.std()
# Out:
# 16.945400921222028

# %% [markdown]
# # *   μ : 33.272
# # *   σ : 268.0117093333333
# # *   σ^2 : 16.371063170525403
# # *   Outlier : Morgan Stanley (91.36%)
